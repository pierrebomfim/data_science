# %% [markdown]
# <a href="https://colab.research.google.com/github/pierrebomfim/data_science/blob/master/Panorama_do_COVID_19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img alt="Colaboratory logo" width="15%" src="https://raw.githubusercontent.com/carlosfab/escola-data-science/master/img/novo_logo_bg_claro.png">
#
# #### **Data Science na Prática 3.0**
# *by Pierre Bomfim*
#
# ---

# %% [markdown]
# # Panorama do COVID-19
#
# A Covid-19 é uma infecção respiratória aguda causada pelo coronavírus SARS-CoV-2, potencialmente grave, de elevada transmissibilidade e de distribuição global.
# O  coronavírus SARS-CoV-2 foi observado inicialmente na cidade de Wuhan, China, em dezembro de 2019.
#
# Ele pode ser transmitido durante um aperto de mão (seguido do toque nos olhos, nariz ou boca), por meio da tosse, espirro e gotículas respiratórias contendo o vírus.
#
# A maioria das pessoas que adoece em decorrência da COVID-19 apresenta sintomas leves a moderados e se recupera sem tratamento especial. No entanto, algumas desenvolvem um quadro grave e precisam de atendimento médico.
#
# Em 2020, devido ao espalhamento geográfico da doença, com insidência em praticamente todos os lugares do mundo, a Organização Mundial de Saúde passou a tratar o surto de Covid-19 como uma pandemia.
#
# Fonte: [Ministério da Saúde](https://www.gov.br/saude/pt-br/coronavirus) | [OMS](https://www.paho.org/pt/covid19/historico-da-pandemia-covid-19)
#
# <center><img alt="Colaboratory logo" width="50%" src="https://cdn.pixabay.com/photo/2021/12/25/07/20/covid-6892470_960_720.jpg"></center>
#
# A pandemia do Covid-19 causou inúmeros danos nos quartro cantos do mundo.Causou a superlotação de clínicas e hospitais e também a escassez de medicamentos e suprimentos hospitalares. Devido ao rápido crescimento do número de contaminações, aliado à falta de informações sobre a doença, os governos e autoridade foram levados a adotar medidas drásticas de contigência, para tentar barra o anvanço da pandemia.
#
# A internet possibilitou um acesso globalizado à informação, popularizado principalmente pelas redes sociais. Porém, pela falta de informações acerca dessa nova doença, das suas características, sintomas, transmissão, tratamento, etc, e pela falta de dados confiáveis, essa pandemia foi marcada por uma verdadeira *guerra midiática*, onde combatiam entre si grupos ideológicos diversos, governos e pessoas comuns, estas tomada por um medo generalizado.
#
# Com a contenção do avanço da doença, as autoridades já sinalizam o fim da pandemia. Agora, temos dados mais claros sobre o que ocorreu e é isto que pretendemos analisar aqui.

# %% [markdown]
# ## Obtenção dos Dados
#
# Os dados utilizados para esta análise foram disponibilizados pelo projeto *Our World in Data*, criado pela ONG *Global Change Data Lab* em parceria com a *University of Oxford*, no Reino Unido. Tem como objetivo criar uma consciência sobre os grandes problemas do mundo (pobreza, guerras, doenças, fome, meio ambiente, etc) atráves de dados acessíveis e compreensíveis.
# O dataset está disponível em repositório público, onde se encontra os arquivos disponíveis em formato CSV, XLSX e JSON. Também está disponível e bem documentado as fontes de dados para criação do dataset, autores e tipo de licensa. Você poderá acessar o repositório clicando no link abaixo:
#  - [Data on COVID-19 (coronavirus) by Our World in Data](https://github.com/owid/covid-19-data/blob/master/public/data/README.md)
#
# Os dados estão classificados em categorias principais. Segue, abaixo, a categoria, a fonte, a frequência de atualização e o número de países estudados:
#  - **Vacinação** - dados adquiridos pela equipe OWID (Our World in Data), atualizado diariamente, com informações sobre 218 países;
#  - **Testes** - dados adquiridos pela equipe OWID, com informações sobre 218 países. Esse conjunto de dados deixou de ser atualizado em 23 de Junho de 2022. Segundo o [anúncio oficial](https://github.com/owid/covid-19-data/discussions/2667), a diferença entre a metodologia utilizada pelos países se tornaram muito diferente e os variados métodos de testagem (PCR, antígeno, etc) reportados estavam cada vez mais sem clareza. Além disso, os critérios para confirmação de caso estavam em divergência crescente entre os países. Dessa forma, ficou complicado harmonizar as definições sobre os dados de forma global;
#
#  [Neste artigo](https://ourworldindata.org/coronavirus-testing#our-checklist-for-covid-19-testing-data), você encontra um checklist de questões para entender os dados de testes, informações sobre a cobertura temporal e geogáfica do dados e informações detalhadas sobre as fontes de dados em cada país;
#
#
#  - **Hospital e UTI** - dados adquiridos pela equipe OWID (Our World in Data), atualizado diariamente, com informações sobre 47 países.
#  A lista completa das fontes de cada país pode ser encontrada [aqui](https://github.com/owid/covid-19-data/blob/master/public/data/hospitalizations/locations.csv);
#
#
#  - **Casos confirmados** e **Mortes confirmadas** - dados do JHU CSSE (Johns Hopkins University), atualizado diariamente, com informações sobre 219 países.
#  Mais informações sobre a data e a metodologia utilizada para obtenção dos dados podem ser encontradas [aqui](https://ourworldindata.org/coronavirus-source-data).
#  Observação: Os dados de casos confirmados e mortes são obtidos pela data do relatório e não pela data do ocorrido (teste ou morte). Portanto, o numero relatado em determinado dia não representa, necessariamente, o dia de casos naquele dia. Isso ocorre pois existe uma certa demora para que um novo caso ou morte seja incluído como dado nas estatísticas. Também pode se observar uma mudança repentina nas sérias temporais, para mais ou para menos, quando um país corrige seus dados históricos, uma vez que pode ter substimado ou superestimado o numero de casos ou mortes;
#
#  - **Taxa de reprodução** - dados por Arroyo-Marioli F, Bullano F, Kucinskas S, Rondón-Moreno C, atualizado diariamente, com informações sobre 195 países;
#  - **Política de enfrentamento** - dados do rastreador de políticas públicas de enfrentamento à Covid-19 ( Oxford), atualizado diariamente, com informações sobre 187 países;
#  - **Outras variáveis de interesse** - dados de organizações internacionais (ONU, Banco Mundial, OECD, etc), sem frequência de atualização, com informações sobre 241 países;
#
#
# No Brasil, os dados são oficialmente fornecidos pelo Ministério da Saúde, neste [portal](https://covid.saude.gov.br/) especial para o Covid-19.

# %% [markdown]
# ### Dicionário de Variáveis
#
# #### Casos confirmados
# (Números podem conter casos prováveis, onde reportados)
# - `total_cases`	- Total de casos confirmados de COVID-19.
# - `new_cases`	- Novos casos confirmados de COVID-19. Em casos raros, onde a fonte dos dados reportam uma alteração diária negativa, para coreção de dados, esses valores serão setados como 'NA'.
# - `new_cases_smoothed` - Novos casos cofirmados de COVID-19 (dado de 7 dias suavizado).
# - `total_cases_per_million` -	Total de casos confirmados de COVID-19 por um milhão de pessoas.
# - `new_cases_per_million` - Novos casos confirmados por um milhão de pessoas.
# - `new_cases_smoothed_per_million`	- Novos casos confirmados de COVID-19 (dados tratados de 7 dias) por um milhão de pessoas. dados tratados de 7 dias.
#
# #### Mortes confirmadas
#
# (Números podem conter casos prováveis, onde reportados)
# - `total_deaths` - 	Total de mortes por COVID-19.
# - `new_deaths` - Novas mortes por COVID-19. Em casos raros, onde a fonte dos dados reportam uma alteração diária negativa, para coreção de dados, esses valores serão setados como 'NA'.
# - `new_deaths_smoothed`	- Novas mortes atribuidas ao COVID-19 (dado de 7 dias suavizado).
# - `total_deaths_per_million` - Total de mortes atribuidas ao COVID-19 por um milhão de pessoas.
# - `new_deaths_per_million` -	Novas mortes atribuidas ao COVID-19 por um milhão de pessoas.
# - `new_deaths_smoothed_per_million`	- Novas mortes atribuidas ao COVID-19 (dado de 7 dias suavizado) por um milhão de pessoas.
#
# Observação:
# Devido à variedade de protocolos e à dificuldade em atribuir corretamente a causa da morte, o número de mortes confirmadas pode não representar precisamento o número verdadeiro de mortes causadas por COVID-19.
#
# #### Mortalidade
#
# - `excess_mortality` - Diferença entre o número de mortes reportados semanalmente ou mensalmente em 2020-2021 e o número de mortes projetado para o mesmo período no ano anterior, em porcentagem.
# - `excess_mortality_cumulative` - Diferença entre o número acumulado de mortes desde 01 de Janeiro de 2020 e a projeção de mortes acumulada para o mesmo período no ano anterior, em porcentagem.
# - `excess_mortality_cumulative_absolute` - Diferença acumulada entre o numero reportado de mortes desde 01 de janeiro de 2020 e a projeção do número de mortes para o mesmo período no ano anterior.
# - `excess_mortality_cumulative_per_million`	- Diferença acumulada entre o numero reportado de mortes desde 01 de janeiro de 2020 e a projeção do número de mortes para o mesmo período no ano anterior, por um milhão de pessoas.
#
# [Click aqui](https://github.com/owid/covid-19-data/tree/master/public/data/excess_mortality) para mais informações sobre essa variável.
#
# #### Hospital & ICU
#
# - `icu_patients` - Número de pacientes de COVID-19 em unidade de tratamento intensivo(UTI) em determinado dia.
# - `icu_patients_per_million` - Número de pacientes de COVID-19 em unidade de tratamento intensivo(UTI) em determinado dia, por um milhão de pessoas.
# - `hosp_patients` -	Número de pacientes de COVID-19 no hospital, em determinado dia.
# - `hosp_patients_per_million`	-	Número de pacientes de COVID-19 no hospital, em determinado dia, por um milhão de pessoas.
# - `weekly_icu_admissions`	- Número de novos pacientes de COVID-19 admitidos na UTI em dada semana (data reportada e os seis dias anteriores).
# - `weekly_icu_admissions_per_million`	- Número de novos pacientes de COVID-19 admitidos na UTI em dada semana (data reportada e os seis dias anteriores), por um milhão de pessoas.
# - `weekly_hosp_admissions`	- Número de novos pacientes de COVID-19 admitidos no hospital em dada semana (data reportada e os seis dias anteriores).
# - `weekly_hosp_admissions_per_million`	- Número de novos pacientes de COVID-19 admitidos na UTI em dada semana (data reportada e os seis dias anteriores), por um milhão de pessoas.
#
# #### Políticas de enfrentamento
#
# - `stringency_index` - Índice de rigidez das políticas públicas de enfrentamente: métrica com base em 9 indicadores de ações públicas, incluindo fechamento de escolas, fechamento de locais de trabalho e proibição de viagens, redimensionado para um valor de 0 a 100, onde 100 é igual à medida mais rigorosa.
#
# #### Taxa de reprodução
#
# - `reproduction_rate`	- Estimativa em tempo real da taxa de reprodução (R) do COVID-19.
#
# [Cliqui aqui](https://github.com/crondonm/TrackingR/tree/main/Estimates-Database) para mais informações sobre essa variável.
#
# #### Testagem
#
# - `total_tests`	- Total de testes para COVID-19.
# - `new_tests`	- Novos testes para COVID-19 (somente calculado para dias consecutivos).
# - `total_tests_per_thousand`- Total de testes para COVID-19 por  mil pessoas.
# - `new_tests_per_thousand` - Novos testes para COVID-19 por mil pessoas.
# - `new_tests_smoothed` - Novos testes para COVID-19 (dado de 7 dias suavizado). Para os países que não reportam os dados de testes diariamente, é considerado que os valores são alterados igualmente, por dia, em qualquer período em que não houver dados reportados. Isso produz uma série completa de número diários, atravez da qual é calculada a média móvel de sete dias.
# - `new_tests_smoothed_per_thousand`	- Novos testes para COVID-19 (dado de 7 dias suavizado), por mil pessoas.
# - `positive_rate`	-  A porção dos testes de COVID-19 que são positivos, dado como média móvel de sete dias (é o inverso de `tests_per_case`).
# - `tests_per_case` - Testes aplicados por cada novo caso de COVID-19 confirmado, dado como média móvel dos últimos sete dias ((é o inverso de `positive_rate`).
# - `tests_units` - Unidade utilizada pelo país para relatar seus dados de teste. Um conjunto de dados de um país não pode conter diferentes unidades. As unidades válidas são `pessoas testadas` (número de pessoas testadas), `testes realizados` (número de testes realizados. Uma única pessoa pode ser testada mais de uma vez em um determinado dia) e `amostras testadas` (número de amostras testadas. Em alguns casos, mais de uma amostra pode ser necessária para realizar um determinado teste.)
#
# #### Vacinação
#
# - `total_vaccinations`	- Número total de doses de vacina para COVID-19 administradas.
# - `people_vaccinated`	- Número total de pessoas que receberam ao menos uma dose de vacina.
# - `people_fully_vaccinated`	- Número total de pessoas que receberam todas as doses prescritas no protocolo de vacinação inicial.
# - `total_boosters` - Número total de doses de reforço administradas (aquelas além do protocolo).
# - `new_vaccinations`	- Novas doses de vacina contra COVID-19 administradas (somente calculado por dias consecutivos).
#
# - `new_vaccinations_smoothed` - Novas doses de vacina contra COVID-19 administradas (dado de 7 dias suavizado). Para os países que não reportam os dados de vacinação diariamente, é considerado que os valores são alterados igualmente, por dia, em qualquer período em que não houver dados reportados. Isso produz uma série completa de número diários, atravez da qual é calculada a média móvel de sete dias.
#
# - `total_vaccinations_per_hundred` - Número total de doses administradas por 100 pessoas na população total.
# - `people_vaccinated_per_hundred`	- Número total de pessoas que receberam ao menos uma dose de vacina, por 100 pessoas.
# - `people_fully_vaccinated_per_hundred`	- Número total de pessoas que receveram todas as doses prescritas de vacina, por 100 pessoas.
# - `total_boosters_per_hundred` - Número total de doses de reforço administradas , por cem pessoas.
# - `new_vaccinations_smoothed_per_million`	Novas doses de vacina contra COVID-19 administradas (dado de 7 dias suavizado), por um milhão de pessoas.
# - `new_people_vaccinated_smoothed` - Número diário de pessoas que receberam a primeira dose de vacina (dado de 7 dias suavizado).
# - `new_people_vaccinated_smoothed_per_hundred`	- Número diário de pessoas que receberam a primeira dose de vacina (dado de 7 dias suavizado), por cem pessoas.
#
# #### Outros
#
# - `iso_code` - Código do país, padronizado pela [ISO 3166](https://www.iso.org/iso-3166-country-codes.html), com três letras. Para as regiões pre-definidas pela OWID, as entradas contém o prefixo 'OWID_'.
# - `continent`	- Continente .
# - `location` - Localização geográfica. Entradas como 'International' considera locais especiais, a exemplo dos cruzeiros "Diamond Princess" and "MS Zaandam".
# - `date` - Data da observação.
# - `population` -	População (valores da ultima atualização disponível). Confira a [lista](https://github.com/owid/covid-19-data/blob/master/scripts/input/un/population_latest.csv) das fontes utilizadas.
# - `population_density` - Densidade populacional, calculada pela divisão do número de pessoas pela área, medida em km2 (valores da ultima atualização disponível).
# - `median_age` - Idade média da população, pela projeção da ONU para 2020.
# - `aged_65_older`	- Parte da população com 65 anos ou mais de idade.
# - `aged_70_older`	- Parte da população com 70 anos ou mais de idade, em 2015.
# - `gdp_per_capita` - Produto Interno Bruto (PIB) dividido pela população total do país.
# - `extreme_poverty`	- Parte da população que vive em estado de 'extrema pobreza', desde 2010.
# - `cardiovasc_death_rate`	- Taxa de mortalidade por doenças cardiovasculares em 2017 (número de mortes anual por 100 mil pessoas)
# - `diabetes_prevalence`	- Prevalência de diabetes (% da população entre 20 e 79 anos) em 2017.
# - `female_smoker`s - Quantidade de mulheres fumantes.
# - `male_smokers`	- Quantidade de homens fumantes.
# - `handwashing_facilities` - 	Parte da população com acesso básico à itens de higiene pessoal.
# - `hospital_beds_per_thousand` - Leitos de hospital por mil pessoas (desde 2010).
# - `life_expectancy`	- Expectativa de vida ao nascer, em 2019.
# - `human_development_index` - Índice de desenvolvimento humano ( avalia três dimensões básica do ser humano: uma vida longa e saudável, conhecimento e condições de vida decentes). Valores de 2019. [Saiba mais](http://hdr.undp.org/en/indicators/137506) sobre esse indicador.

# %% [markdown]
# **Importando os dados do COVID-19**

# %%
# importar as bibliotecas necessárias
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.dates as mdates
import matplotlib.cbook as cbook
import matplotlib.dates as dates
import matplotlib.ticker as ticker
from matplotlib.dates import DateFormatter
from matplotlib.ticker import FuncFormatter


# importar o dataset COVID-19 para um DataaFrame
DATA_PATH = 'https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/owid-covid-data.csv'
df = pd.read_csv(DATA_PATH)

# %% [markdown]
# ## Análise Exploratória dos Dados
#
# Neste primeiro momento, iremos realizar uma análise inicial do dataset, conhecer suas características, como tamanho, tipo de variáveis, valores ausentes e formato dos dados de entrada. Desta forma, poderemos adequar o dataset para os fins a que se propõe esta análise.

# %% [markdown]
# **Análise Exploratória Inicial**

# %%
# Visualizar as 5 primeiras entradas
print("Amostra com as 5 primeiras entradas do dataframe: ")
df.head()
# Out:
# Amostra com as 5 primeiras entradas do dataframe:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
# ...

# %%
# Ver tamanho do dataframe
print(f'O Dataframe possui:\n {df.shape[1]} colunas\n {df.shape[0]} linhas\n')

# Ver o nome das colunas
print(f'O Dataframe possui as colunas descritas abaixo:\n {df.columns}\n')

# Ver o tipo das variáveis
print('Os tipos das variáveis são:')
df.dtypes
# Out:
# O Dataframe possui:
#  67 colunas
#  224480 linhas
#
# O Dataframe possui as colunas descritas abaixo:
#  Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
# ...

# %% [markdown]
# A variável `date` possui entradas do tipo `object`. Para melhor funcionamento da análise, vamos convertar para o formato `datetime`:

# %%
# Converte as entradas de date para datetime
df.date = pd.to_datetime(df.date)

# Confirmar alterações
df.dtypes
# Out:
# iso_code                                           object
# continent                                          object
# location                                           object
# date                                       datetime64[ns]
# total_cases                                       float64
#                                                 ...
# human_development_index                           float64
# excess_mortality_cumulative_absolute              float64
# excess_mortality_cumulative                       float64
# excess_mortality                                  float64
# excess_mortality_cumulative_per_million           float64
# Length: 67, dtype: object

# %% [markdown]
# **Valores ausentes**
#
# Aqui, vamos analisar a existência de valores ausentes , por cada coluna, e a porcentagem desse valor com relação ao número absoluto da variável.

# %%
# Ver um resumo dos dados faltantes por coluna, em porcentagem
(df.isnull().sum() / df.shape[0]).sort_values(ascending=False)
# Out:
# weekly_icu_admissions_per_million          0.967079
# weekly_icu_admissions                      0.967079
# excess_mortality_cumulative_per_million    0.965761
# excess_mortality_cumulative                0.965761
# excess_mortality_cumulative_absolute       0.965761
#                                              ...
# total_cases                                0.040877
# population                                 0.005796
# date                                       0.000000
# location                                   0.000000
# iso_code                                   0.000000
# Length: 67, dtype: float64

# %% [markdown]
# ## **COVID-19 no mundo**

# %% [markdown]
# Esta análise tem por objetivo responder as seguintes perguntas:
#
# 1. Quais o valores totais de casos de COVID-19 no mundo
# 2. Qual o número total de mortes por COVID-19
# 3. Quais os paíes com maior número de casos de COVID-19?
# 4. Quais os países com maior número de mortes confirmadas?
# 5. Existe relação entre o número de mortes com o IDH ou PIB do país?
#
#
# Uma vez que os valores são atualizados diariamente no dataset, precisamos filtrar os dados para a data mais recente. Para isso, basta que vejamos o maior valor da coluna date:

# %%
df.date.max()
# Out:
# Timestamp('2022-10-17 00:00:00')

# %% [markdown]
# ### **Total de casos de COVID-19**
#
# Com a data conhecida, vamos analisar os dados de total de casos e mortes, lançados no dataset nesta data:

# %%
# Dados do dataset ordenados por ordem decrescente na grandeza 'total de casos'
df.loc[df.date == '2022-10-14'].sort_values(by="total_cases", ascending=False)[:5]
# Out:
#         iso_code continent        location       date  total_cases  new_cases  \
# 221669  OWID_WRL       NaN           World 2022-10-14  624194044.0   452293.0
# 88229   OWID_HIC       NaN     High income 2022-10-14  387198323.0   413894.0
# 65684   OWID_EUR       NaN          Europe 2022-10-14  233094256.0   267755.0
# 11616   OWID_ASI       NaN            Asia 2022-10-14  187227392.0   135959.0
# 66683   OWID_EUN       NaN  European Union 2022-10-14  171207986.0   251145.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 221669          465860.143     6566258.0      1543.0             1434.143
# 88229           414083.571     2688349.0      1247.0             1094.000
# 65684           273071.714     1950321.0       736.0              640.143
# 11616           133990.286     1488452.0       265.0              256.286
# 66683           240337.571     1154006.0       632.0              460.571
#
# ...

# %% [markdown]
# Vamos criar um dataframe, selecionando apenas os valores mundiais, que estão dispostos com o `iso_code`OWID_WRL. E então, poderemos plotar um gráfico com a evolução dos casos de COVID no mundo.

# %%
# Criar o dataframe df_world apenas com dados com a localidade World (valor mundial)
df_world = df.loc[df.location == "World"]

# %%
# Alterar o tipo de entrada para datetime
df_world.date = pd.to_datetime(df.date)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:5516: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
# Alterar o index do df para datetime
df_world.index = pd.date_range(df_world.date.min(), df.date.max())

# %% [markdown]
# #### Valores acumulados

# %%
# Criar figure e plot space
fig, ax = plt.subplots(figsize=(18, 6))

# Add x-axis and y-axis
ax.bar(df_world.index.values, df_world['total_cases'], color='#b4b2b2')

# Definir o título
ax.set(title="Evolução dos casos de COVID-19 acumulado")

# Formatar a data
date_form = DateFormatter("%b %y")
ax.xaxis.set_major_formatter(date_form)

# Remover as bordas
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)

# Alterar a escala y para a direita
ax.yaxis.tick_right()

# Alterar a unidade do eixo y
def millions(x, pos):
    """The two arguments are the value and tick position."""
    return '{:1.0f}M'.format(x*1e-6)
formatter = FuncFormatter(millions)
ax.yaxis.set_major_formatter(formatter)

#Remover ticks de x e y
plt.tick_params(right = False, bottom = False)

# Plotar caixa de texto
textstr = 'casos confirmados'
cases_value = df_world.total_cases.loc[df_world.date == '2022-10-14'].values
cases = cases_value[0].astype(str)
props = dict(boxstyle='round', facecolor='wheat', alpha=0.0)

cases_value = round(df_world.total_cases.loc[df_world.date == '2022-10-14'].values[0])
cases = str(cases_value)
cases = cases[0:3] + '.' + cases[3:6] + '.' + cases[6:9]

ax.text(0.05, 0.85, cases, transform=ax.transAxes, fontsize=50,
        fontfamily='DejaVu Sans', color='#474747',verticalalignment='top', bbox=props)
ax.text(0.05, 0.70, textstr, transform=ax.transAxes, fontsize=14, color='#474747',
        verticalalignment='top', bbox=props)

# Margens
ax.use_sticky_edges = False

plt.show()

# %% [markdown]
# #### Valores diários

# %%
# Criar figure e plot space
fig, ax = plt.subplots(figsize=(18, 6))

# Add x-axis and y-axis
ax.bar(df_world.index.values, df_world['new_cases'], color='#b4b2b2')

# Definir o título
ax.set(title="Evolução diária dos casos de COVID-19")

# Formatar a data
date_form = DateFormatter("%b %y")
ax.xaxis.set_major_formatter(date_form)

# Remover as bordas
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)

# Alterar a escala y para a direita
ax.yaxis.tick_right()

# Alterar a unidade do eixo y
def millions(x, pos):
    """The two arguments are the value and tick position."""
    return '{:1.0f}M'.format(x*1e-6)
formatter = FuncFormatter(millions)
ax.yaxis.set_major_formatter(formatter)

#Remover ticks de x e y
plt.tick_params(right = False, bottom = False)

# Plotar caixa de texto
textstr = f'casos confirmados \nem 14 de Outubro de 2022'
new_cases_value = df_world.new_cases.loc[df_world.date == '2022-10-14'].values
new_cases = new_cases_value[0].astype(str)
props = dict(boxstyle='round', facecolor='wheat', alpha=0.0)

new_cases_value = round(df_world.new_cases.loc[df_world.date == '2022-10-14'].values[0])
new_cases = str(new_cases_value)
new_cases = new_cases[0:3] + '.' + new_cases[3:6]

ax.text(0.05, 0.85, new_cases, transform=ax.transAxes, fontsize=50,
        fontfamily='DejaVu Sans', color='#474747', verticalalignment='top', bbox=props) 
ax.text(0.05, 0.70, textstr, transform=ax.transAxes, fontsize=14, color='#474747',
        verticalalignment='top', bbox=props)

# Margens
ax.use_sticky_edges = False

plt.show()

# %% [markdown]
# Nos gráficos, observa-se claramente o comportamento da Pandemia do COVID-19 no mundo. O número de casos desde o seu início em 2020 já passam dos 600 milhões. Porém, no gráfico onde mostra os casos lançados diariamente, nota-se que esse valor vem diminuindo. Teve seu pico com aproximadamente de 4 milhões de casos por dia e atualmente com a média abaixo de meio milhão de casos por dia.

# %% [markdown]
# ### **Total de mortes pro COVID-19**
#
# Vejamos abaixo os dados relacionados às mortes por COVID-19

# %% [markdown]
# #### Valores acumulados

# %%
# Criar figure e plot space
fig, ax = plt.subplots(figsize=(18, 6))

# Add x-axis and y-axis
ax.bar(df_world.index.values, df_world['total_deaths'], color='#b4b2b2')

# Definir o título
ax.set(title="Evolução das mortes de COVID-19")

# Formatar a data
date_form = DateFormatter("%b %y")
ax.xaxis.set_major_formatter(date_form)

# Remover as bordas
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)

# Alterar a escala y para a direita
ax.yaxis.tick_right()

# Alterar a unidade do eixo y
def millions(x, pos):
    """The two arguments are the value and tick position."""
    return '{:1.0f}M'.format(x*1e-6)
formatter = FuncFormatter(millions)
ax.yaxis.set_major_formatter(formatter)

#Remover ticks de x e y
plt.tick_params(right = False, bottom = False)

# Plotar caixa de texto
textstr = 'Mortes confirmadas'
deaths_value = df_world.total_deaths.loc[df_world.date == '2022-10-14'].values
deaths = deaths_value[0].astype(str)
props = dict(boxstyle='round', facecolor='wheat', alpha=0.0)

deaths_value = round(df_world.total_deaths.loc[df_world.date == '2022-10-14'].values[0])
deaths = str(deaths_value)
deaths = deaths[0:1] + '.' + deaths[1:4] + '.' + deaths[4:7]

ax.text(0.05, 0.85, deaths, transform=ax.transAxes, fontsize=50,
        fontfamily='DejaVu Sans', color='#474747',verticalalignment='top', bbox=props)
ax.text(0.05, 0.70, textstr, transform=ax.transAxes, fontsize=14, color='#474747',
        verticalalignment='top', bbox=props)

# Margens
ax.use_sticky_edges = False

plt.show()

# %% [markdown]
# #### Valores diários

# %%
# Criar figure e plot space
fig, ax = plt.subplots(figsize=(18, 6))

# Add x-axis and y-axis
ax.bar(df_world.index.values, df_world['new_deaths'], color='#b4b2b2')

# Definir o título
ax.set(title="Evolução diária das mortes por COVID-19")

# Formatar a data
date_form = DateFormatter("%b %y")
ax.xaxis.set_major_formatter(date_form)

# Remover as bordas
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)

# Alterar a escala y para a direita
ax.yaxis.tick_right()

# Alterar a unidade do eixo y
def millions(x, pos):
    """The two arguments are the value and tick position."""
    return '{:1.0f}k'.format(x*1e-3)
formatter = FuncFormatter(millions)
ax.yaxis.set_major_formatter(formatter)

#Remover ticks de x e y
plt.tick_params(right = False, bottom = False)

# Plotar caixa de texto
textstr = f'Mortes confirmadas \nem 14 de Outubro de 2022'
new_deaths_value = df_world.new_deaths.loc[df_world.date == '2022-10-14'].values
new_deaths = new_deaths_value[0].astype(str)
props = dict(boxstyle='round', facecolor='wheat', alpha=0.0)

new_deaths_value = round(df_world.new_deaths.loc[df_world.date == '2022-10-14'].values[0])
new_deaths = str(new_deaths_value)
new_deaths = new_deaths[0:1] + '.' + new_deaths[1:5]

ax.text(0.05, 0.85, new_deaths, transform=ax.transAxes, fontsize=50,
        fontfamily='DejaVu Sans', color='#474747', verticalalignment='top', bbox=props) 
ax.text(0.05, 0.70, textstr, transform=ax.transAxes, fontsize=14, color='#474747',
        verticalalignment='top', bbox=props)

# Margens
ax.use_sticky_edges = False

plt.show()

# %% [markdown]
# As mortes confirmadas atribuídas ao COVID-19 somam mais de 6 milhões, desde o início da pandemia. O pico de mortes diárias foi em Janeiro de 2021, chegando à mais 15 mil mortes de por dia. Atualmente, esse valor está por volta de 1500 mortes diárias.

# %% [markdown]
# ### **Análise por continentes**
#
# Vamos analisar os dados referente aos continentes.

# %%
# Ver quais os continentes 
df.location.loc[df.continent.isna()].unique()
# Out:
# array(['Africa', 'Asia', 'Europe', 'European Union', 'High income',
#        'International', 'Low income', 'Lower middle income',
#        'North America', 'Oceania', 'South America', 'Upper middle income',
#        'World'], dtype=object)

# %%
# Criar um dataframe para cada região
africa = df.loc[df.location == "Africa"]
asia = df.loc[df.location == "Asia"]
europe = df.loc[df.location == "Europe"]
northa = df.loc[df.location == "North America"]
oceania = df.loc[df.location == "Oceania"]
southa = df.loc[df.location == "South America"]

# %%
# Alterar o indice para as datas, em todas as regiões
regions = [africa, asia, europe, northa, oceania, southa]
for place in regions:
  place.index = pd.date_range(place.date.min(), place.date.max())

# %%
# como as datas do inicio das entradas diferem entre as regiões, vou colocar como incio uma data padrão (tentar automatizar depois)
''' nao consegui iterar
for place in regions:
  place = place.drop(place.loc[place.index < '2020-03-01'].index)'''

africa = africa.drop(africa.loc[africa.index < '2020-03-01'].index)
asia = asia.drop(asia.loc[asia.index < '2020-03-01'].index)
europe = europe.drop(europe.loc[europe.index < '2020-03-01'].index)
northa = northa.drop(northa.loc[northa.index < '2020-03-01'].index)
oceania = oceania.drop(oceania.loc[oceania.index < '2020-03-01'].index)
southa = southa.drop(southa.loc[southa.index < '2020-03-01'].index)

# %%
# Criação do gráfico
fig, ax = plt.subplots(figsize=(18, 6))

# Set title and labels for axes
ax.set(title="Evolução dos casos de COVID-19")

# Add x-axis and y-axis
ax.bar(europe.index.values, europe['total_cases'], bottom=asia['total_cases'], color='#c8d65b') 
ax.bar(asia.index.values, asia['total_cases'], bottom=northa['total_cases'], color='#ffbb30')
ax.bar(northa.index.values, northa['total_cases'], bottom=southa['total_cases'], color='#c12592')
ax.bar(southa.index.values, southa['total_cases'], bottom=africa['total_cases'], color='#5200ae')
ax.bar(africa.index.values, africa['total_cases'], bottom=oceania['total_cases'], color='#00ae8f')
ax.bar(oceania.index.values, oceania['total_cases'], color='#0a71d5')

# Define the date format
date_form = DateFormatter("%b %y")
ax.xaxis.set_major_formatter(date_form)

# Remover as bordas
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)

# Alterar a escala y para a direita
ax.yaxis.tick_right()

# Alterar a unidade do eixo y

def millions(x, pos):
    """The two arguments are the value and tick position."""
    return '{:1.0f}M'.format(x*1e-6)
formatter = FuncFormatter(millions)
ax.yaxis.set_major_formatter(formatter)

#Remover ticks de x e y
plt.tick_params(right = False, bottom = False)

# Plotar caixa de texto
textstr = 'Situação por continentes'

europe_value = europe.total_cases.loc[europe.date == '2022-10-14'].values
europe_cases = europe_value[0].astype(str)
europe_cases = europe_cases[0:3] + '.' + europe_cases[3:6] + '.' + europe_cases[6:9]
europe_text = f'Europa                          {europe_cases}'

northa_value = northa.total_cases.loc[northa.date == '2022-10-14'].values
northa_cases = northa_value[0].astype(str)
northa_cases = northa_cases[0:3] + '.' + northa_cases[3:6] + '.' + northa_cases[6:9]
northa_text = f'América do Norte         {northa_cases}'

asia_value = asia.total_cases.loc[asia.date == '2022-10-14'].values
asia_cases = asia_value[0].astype(str)
asia_cases = asia_cases[0:3] + '.' + asia_cases[3:6] + '.' + asia_cases[6:9]
asia_text = f'Asia                              {asia_cases}'

southa_value = southa.total_cases.loc[southa.date == '2022-10-14'].values
southa_cases = southa_value[0].astype(str)
southa_cases = southa_cases[0:2] + '.' + southa_cases[2:5] + '.' + southa_cases[5:8]
southa_text = f'América do Sul               {southa_cases}'

oceania_value = oceania.total_cases.loc[oceania.date == '2022-10-14'].values
oceania_cases = oceania_value[0].astype(str)
oceania_cases = oceania_cases[0:2] + '.' + oceania_cases[2:5] + '.' + oceania_cases[5:8]
oceania_text = f'Oceania                          {oceania_cases}'

africa_value = africa.total_cases.loc[africa.date == '2022-10-14'].values
africa_cases = africa_value[0].astype(str)
africa_cases = africa_cases[0:2] + '.' + africa_cases[2:5] + '.' + africa_cases[5:8]
africa_text = f'África                              {africa_cases}'

props = dict(boxstyle='round', facecolor='wheat', alpha=0.0)

ax.text(0.05, 0.95, textstr, transform=ax.transAxes, fontsize=25,
        fontfamily='DejaVu Sans', color='#4c4c4c', verticalalignment='top', bbox=props)

ax.text(0.05, 0.80, europe_text, transform=ax.transAxes, fontsize=20,
        fontfamily='DejaVu Sans', color='#c8d65b', verticalalignment='top', bbox=props)

ax.text(0.05, 0.73, asia_text, transform=ax.transAxes, fontsize=20,
        fontfamily='DejaVu Sans', color='#ffbb30', verticalalignment='top', bbox=props)

ax.text(0.05, 0.66, northa_text, transform=ax.transAxes, fontsize=20,
        fontfamily='DejaVu Sans', color='#c12592', verticalalignment='top', bbox=props)

ax.text(0.05, 0.59, southa_text, transform=ax.transAxes, fontsize=20,
        fontfamily='DejaVu Sans', color='#5200ae', verticalalignment='top', bbox=props)

ax.text(0.05, 0.52, oceania_text, transform=ax.transAxes, fontsize=20,
        fontfamily='DejaVu Sans', color='#00ae8f', verticalalignment='top', bbox=props)

ax.text(0.05, 0.45, africa_text, transform=ax.transAxes, fontsize=20,
        fontfamily='DejaVu Sans', color='#0a71d5', verticalalignment='top', bbox=props)

plt.show()

# %% [markdown]
# observamos que a Europa lidera com o maior número de casos e a África segue com o menor núemro de casos.

# %%
# Criação do gráfico
fig, ax = plt.subplots(figsize=(18, 6))

# Set title and labels for axes
ax.set(title="Evolução diária dos casos de COVID-19")

# Add x-axis and y-axis
ax.bar(europe.index.values, europe['new_cases'], bottom=asia['new_cases'], color='#c8d65b')  
ax.bar(asia.index.values, asia['new_cases'], bottom=northa['new_cases'], color='#ffbb30')
ax.bar(northa.index.values, northa['new_cases'], bottom=southa['new_cases'], color='#c12592')
ax.bar(southa.index.values, southa['new_cases'], bottom=africa['new_cases'], color='#5200ae')
ax.bar(africa.index.values, africa['new_cases'], bottom=oceania['new_cases'], color='#00ae8f')
ax.bar(oceania.index.values, oceania['new_cases'], color='#0a71d5')

# Define the date format
date_form = DateFormatter("%b %y")
ax.xaxis.set_major_formatter(date_form)

# Remover as bordas
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)

# Alterar a escala y para a direita
ax.yaxis.tick_right()

# Alterar a unidade do eixo y
def millions(x, pos):
    """The two arguments are the value and tick position."""
    return '{:1.0f}M'.format(x*1e-5)
formatter = FuncFormatter(millions)
ax.yaxis.set_major_formatter(formatter)

#Remover ticks de x e y
plt.tick_params(right = False, bottom = False)

# Plotar caixa de texto
textstr = 'Situação em 14 de Outubro de 2022'

europe_value = europe.new_cases.loc[europe.date == '2022-10-14'].values
europe_cases = europe_value[0].astype(str)
europe_cases = europe_cases[0:3] + '.' + europe_cases[3:6]
europe_text = f'Europa                          {europe_cases}'

asia_value = asia.new_cases.loc[asia.date == '2022-10-14'].values
asia_cases = asia_value[0].astype(str)
asia_cases = asia_cases[0:3] + '.' + asia_cases[3:6]
asia_text = f'Asia                              {asia_cases}'

northa_value = northa.new_cases.loc[northa.date == '2022-10-14'].values
northa_cases = northa_value[0].astype(str)
northa_cases = northa_cases[0:2] + '.' + northa_cases[2:5]
northa_text = f'América do Norte           {northa_cases}'

southa_value = southa.new_cases.loc[southa.date == '2022-10-14'].values
southa_cases = southa_value[0].astype(str)
southa_cases = southa_cases[0:2] + '.' + southa_cases[2:5]
southa_text = f'América do Sul               {southa_cases}'

oceania_value = oceania.new_cases.loc[oceania.date == '2022-10-14'].values
oceania_cases = oceania_value[0].astype(str)
oceania_cases = oceania_cases[0:1] + '.' + oceania_cases[1:4]
oceania_text = f'Oceania                            {oceania_cases}'

africa_value = africa.new_cases.loc[africa.date == '2022-10-14'].values
africa_cases = africa_value[0].astype(str)
africa_cases = africa_cases[0:3] 
africa_text = f'África                                   {africa_cases}'

props = dict(boxstyle='round', facecolor='wheat', alpha=0.0)

ax.text(0.05, 0.95, textstr, transform=ax.transAxes, fontsize=25,
        fontfamily='DejaVu Sans', color='#4c4c4c', verticalalignment='top', bbox=props)

ax.text(0.05, 0.80, europe_text, transform=ax.transAxes, fontsize=20,
        fontfamily='DejaVu Sans', color='#c8d65b', verticalalignment='top', bbox=props)       

ax.text(0.05, 0.73, asia_text, transform=ax.transAxes, fontsize=20,
        fontfamily='DejaVu Sans', color='#ffbb30', verticalalignment='top', bbox=props)

ax.text(0.05, 0.66, northa_text, transform=ax.transAxes, fontsize=20,
        fontfamily='DejaVu Sans', color='#c12592', verticalalignment='top', bbox=props)

ax.text(0.05, 0.59, southa_text, transform=ax.transAxes, fontsize=20,
        fontfamily='DejaVu Sans', color='#5200ae', verticalalignment='top', bbox=props)

ax.text(0.05, 0.52, oceania_text, transform=ax.transAxes, fontsize=20,
        fontfamily='DejaVu Sans', color='#00ae8f', verticalalignment='top', bbox=props)

ax.text(0.05, 0.45, africa_text, transform=ax.transAxes, fontsize=20,
        fontfamily='DejaVu Sans', color='#0a71d5', verticalalignment='top', bbox=props)

plt.show()

# %% [markdown]
# Em Janeiro de 2022, a Europa chegou a registrar mais de 2 milhões de casos diários de COVID-19. Atualmnte, esse valor é cerca de 200 mil casos diários registrados.

# %% [markdown]
# ### Ranking dos número dos casos
#
# Seguindo com a análise, vamos pesquisar sobre os países que lideram o ranking de número de casos e mortes.
# As entradas que possuem o prefixo 'OWID_' na coluna `iso_code` se referem a regiões específicas, como continentes, predeterminadas pela fonte dos dados.
# Observamos que nessas linhas, os valores para `continent` são `NaN`. Dessa forma, iremos excluir essas entradas, para possibilitar uma melhor visualização.

# %%
# Criar datafra  para entradas em iso_code apenas para países, removendo os valores ausentes do df original
df_countries = df.dropna(subset=['continent'], axis=0)

# Dados de df_countries ordenados de forma decrescente para o 'total de casos'
total_cases_countries_ranking = df_countries.loc[df_countries.date == '2022-10-14'].sort_values(by="total_cases", ascending=False)[:5]
total_cases_countries_ranking
# Out:
#        iso_code      continent       location       date  total_cases  \
# 212615      USA  North America  United States 2022-10-14   96940217.0
# 93093       IND           Asia          India 2022-10-14   44626427.0
# 71551       FRA         Europe         France 2022-10-14   36223509.0
# 28819       BRA  South America         Brazil 2022-10-14   34746462.0
# 76353       DEU         Europe        Germany 2022-10-14   34608835.0
#
#         new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 212615    28163.0           35854.571     1065076.0       278.0
# 93093      2430.0            2475.571      528874.0        17.0
# 71551     58695.0           56416.286      155885.0        79.0
# 28819      6597.0            5604.143      687144.0        75.0
# 76353     91508.0           94314.714      151420.0       160.0
#
#         new_deaths_smoothed  ...  female_smokers  male_smokers  \
# 212615              347.143  ...            19.1          24.6
# ...

# %% [markdown]
# Vamos plotar um gráfico de barras para melhor visualização

# %%
#criando a fig e o ax no matplotlib
fig, ax = plt.subplots(figsize=(8,6))

#criando novamente o gráfico
sns.barplot(x=total_cases_countries_ranking['iso_code'], 
            y=total_cases_countries_ranking['total_cases'],
            data = total_cases_countries_ranking,
            ax=ax) 

#modificação do fundo
ax.set_frame_on(False) # retirando o Frame (retângulo que encobre os gráficos)

#adicionando um título
ax.set_title('Número de casos de COVID-19', # texto do título
             loc='left', # posicionamento do título no Axes
             pad=30, # Distanciamento do título com outros objetos
             fontdict={'fontsize':20}, # Tamanho da fonte utilizado
             color='#3f3f4e') # cor da fonte em hexadecimal

#retirando o eixo y
ax.get_yaxis().set_visible(False) # retirando o eixo Y

#retirando os ticks do eixo x
ax.tick_params(axis='x', # escolhendo os ticks do eixo x
               length=0, # colocamos os ticks de tamanho zero, compare com os desenhos de cima
               labelsize=12, # tamanho da fonte para os eixos
               colors='dimgrey') # cor da fonte para o eixo x

#ajustando o título
ax.set_xlabel('Países', # título que queremos colocar na parte horizontal (em baixo)
              labelpad=10, # distanciamento deste título com outros objetos
              fontdict={'fontsize':14}, # tamanho da fonte utilizado
              color='#4c4c4c') # cor da fonte em hexadecimal


#colocando os rótulos
for retangulo in ax.patches:
  ax.text(retangulo.get_x() + retangulo.get_width() / 2, retangulo.get_height() * 1.05, 
          '{:,}'.format(int(retangulo.get_height())).replace(',','.'), ha = 'center')

#plotando o gráfico
plt.tight_layout();

# %% [markdown]
# Observamos que os países que lideram o ranking do número de casos, em 14 de Outubro de 2022, são:
#
#
# 1. Estados Unidos - 96.940.217 de casos
# 2. Índia - 44.626.427 de casos
# 3. França - 36.223.509 de casos
# 4. Brasil - 34.746.462 de casos
# 5. Alemanha - 34.608.835 de casos
#
# Desses países, vamos analisar os números relacionado à *renda per capita* de cada país.

# %%
#criando a fig e o ax no matplotlib
fig, ax = plt.subplots(figsize=(8,6))

#criando novamente o gráfico
sns.barplot(x=total_cases_countries_ranking['iso_code'], 
            y=total_cases_countries_ranking['gdp_per_capita'],
            data = total_cases_countries_ranking,
            ax=ax) 

#modificação do fundo
ax.set_frame_on(False) # retirando o Frame (retângulo que encobre os gráficos)

#adicionando um título
ax.set_title('GDP per capita - em USD', # texto do título
             loc='left', # posicionamento do título no Axes
             pad=30, # Distanciamento do título com outros objetos
             fontdict={'fontsize':20}, # Tamanho da fonte utilizado
             color='#3f3f4e') # cor da fonte em hexadecimal

#retirando o eixo y
ax.get_yaxis().set_visible(False) # retirando o eixo Y

#retirando os ticks do eixo x
ax.tick_params(axis='x', # escolhendo os ticks do eixo x
               length=0, # colocamos os ticks de tamanho zero, compare com os desenhos de cima
               labelsize=12, # tamanho da fonte para os eixos
               colors='dimgrey') # cor da fonte para o eixo x

#ajustando o título
ax.set_xlabel('Países', # título que queremos colocar na parte horizontal (em baixo)
              labelpad=10, # distanciamento deste título com outros objetos
              fontdict={'fontsize':14}, # tamanho da fonte utilizado
              color='#4c4c4c') # cor da fonte em hexadecimal


#colocando os rótulos
for retangulo in ax.patches:
  ax.text(retangulo.get_x() + retangulo.get_width() / 2, retangulo.get_height() * 1.05, 
          '{:,}'.format(int(retangulo.get_height())).replace(',','.'), ha = 'center')

#plotando o gráfico
plt.tight_layout();

# %% [markdown]
# Nota-se que o ranking de casos de COVID-19 não está diretamente relacionado ao índice que mede à prosperidade dos países.

# %% [markdown]
# ### **Ranking do número de mortes**
#
# Vejamos agora o ranking dos países em número de mortes por COVID-19:

# %%
total_deaths_countries_ranking = df_countries.loc[df_countries.date == '2022-10-14'].sort_values(by="total_deaths", ascending=False)[:5]
total_deaths_countries_ranking
# Out:
#        iso_code      continent       location       date  total_cases  \
# 212615      USA  North America  United States 2022-10-14   96940217.0
# 28819       BRA  South America         Brazil 2022-10-14   34746462.0
# 93093       IND           Asia          India 2022-10-14   44626427.0
# 167486      RUS         Europe         Russia 2022-10-14   20975381.0
# 130637      MEX  North America         Mexico 2022-10-14    7100886.0
#
#         new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 212615    28163.0           35854.571     1065076.0       278.0
# 28819      6597.0            5604.143      687144.0        75.0
# 93093      2430.0            2475.571      528874.0        17.0
# 167486    14579.0           16260.000      380854.0        97.0
# 130637        0.0             741.429      330254.0         0.0
#
#         new_deaths_smoothed  ...  female_smokers  male_smokers  \
# 212615              347.143  ...            19.1          24.6
# ...

# %%
#criando a fig e o ax no matplotlib
fig, ax = plt.subplots(figsize=(8,6))

#criando novamente o gráfico
sns.barplot(x=total_deaths_countries_ranking['iso_code'], 
            y=total_deaths_countries_ranking['total_deaths'],
            data = total_deaths_countries_ranking,
            ax=ax) 

#modificação do fundo
ax.set_frame_on(False) # retirando o Frame (retângulo que encobre os gráficos)

#adicionando um título
ax.set_title('Número de mortes por COVID-19', # texto do título
             loc='left', # posicionamento do título no Axes
             pad=30, # Distanciamento do título com outros objetos
             fontdict={'fontsize':20}, # Tamanho da fonte utilizado
             color='#3f3f4e') # cor da fonte em hexadecimal

#retirando o eixo y
ax.get_yaxis().set_visible(False)

#retirando os ticks do eixo x
ax.tick_params(axis='x', # escolhendo os ticks do eixo x
               length=0, # colocamos os ticks de tamanho zero, compare com os desenhos de cima
               labelsize=12, # tamanho da fonte para os eixos
               colors='dimgrey') # cor da fonte para o eixo x

#ajustando o título
ax.set_xlabel('Países', # título que queremos colocar na parte horizontal (em baixo)
              labelpad=10, # distanciamento deste título com outros objetos
              fontdict={'fontsize':14}, # tamanho da fonte utilizado
              color='#4c4c4c') # cor da fonte em hexadecimal


#colocando os rótulos
for retangulo in ax.patches:
  ax.text(retangulo.get_x() + retangulo.get_width() / 2, retangulo.get_height() * 1.05, 
          '{:,}'.format(int(retangulo.get_height())).replace(',','.'), ha = 'center')

#plotando o gráfico
plt.tight_layout();

# %% [markdown]
# Notamos que, dos 5 países com maior número de casos, apenas estão no entre os que possuem maior número de mortes:
#
# 1. Estados Unidos - 1.065.076 mortes
# 2. Brasil - 687.144 mortes
# 3. Índia - 528.874 mortes
# 4. Rússia - 380.854 mortes
# 5. México - 330.254 mortes

# %% [markdown]
# ### **Matriz de correlacionamento**
#
# Com os dados relacionados à saúde nos países, bem como do índice de desenvolvimento humano, veremos a correlação destes dados com o número de mortes. Para isso, criaremos uma matriz de correlação e um *heatmap*.

# %%
# criar uma matriz de correlação
corr = df_countries[['total_deaths', 'extreme_poverty', 'cardiovasc_death_rate',
 'diabetes_prevalence', 'hospital_beds_per_thousand', 'human_development_index']].corr()

# mostrar a matriz de correlação
display(corr)
# Out:
#                             total_deaths  extreme_poverty  \
# total_deaths                    1.000000        -0.135493
# extreme_poverty                -0.135493         1.000000
# cardiovasc_death_rate          -0.112534         0.190682
# diabetes_prevalence             0.021555        -0.393304
# hospital_beds_per_thousand      0.008842        -0.440963
# human_development_index         0.153777        -0.777599
#
#                             cardiovasc_death_rate  diabetes_prevalence  \
# total_deaths                            -0.112534             0.021555
# extreme_poverty                          0.190682            -0.393304
# cardiovasc_death_rate                    1.000000             0.120629
# diabetes_prevalence                      0.120629             1.000000
# hospital_beds_per_thousand               0.036028            -0.083789
# human_development_index                 -0.424386             0.208924
#
# ...

# %%
# plotar um heatmap a partir das correlações
sns.heatmap(corr, cmap='RdBu', fmt='.2f', square=True, linecolor='white', annot=True);

# %% [markdown]
# ## **COVID-19 no Brasil**
#
# Como vimos anteriormente, o Brasil foi o 4º país com o maior número de casos e o 2º com o maior número de mortes por COIVD-19.
#
# Faremos uma análse resumida, onde pretendemos responder as questões abaixo:
#
# * Quando foi registrada a primeira morte no Brasil?
# * Quantos dias demorou para registrarmos a primeira morte, considerando o primeiro caso de COVID-19 registrado?
# * Plotar gráficos de linha em escalas linear e logarítmica para os casos totais e mortes totais.

# %%
# Criar uma cópia do DataFrame apenas com o Brasil
df_brasil = df.loc[df.location == "Brazil"].copy()
df_brasil.head()
# Out:
#       iso_code      continent location       date  total_cases  new_cases  \
# 27858      BRA  South America   Brazil 2020-02-26          1.0        1.0
# 27859      BRA  South America   Brazil 2020-02-27          1.0        0.0
# 27860      BRA  South America   Brazil 2020-02-28          1.0        0.0
# 27861      BRA  South America   Brazil 2020-02-29          2.0        1.0
# 27862      BRA  South America   Brazil 2020-03-01          2.0        0.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 27858                 NaN           NaN         NaN                  NaN  ...
# 27859                 NaN           NaN         NaN                  NaN  ...
# 27860                 NaN           NaN         NaN                  NaN  ...
# 27861                 NaN           NaN         NaN                  NaN  ...
# 27862                 NaN           NaN         NaN                  NaN  ...
#
# ...

# %%
print(df_brasil.date.min())
print(df_brasil.date.loc[df_brasil.new_deaths == 1])
# Out:
# 2020-02-26 00:00:00
# 27878   2020-03-17
# Name: date, dtype: datetime64[ns]

# %% [markdown]
# O primeiro caso de COVID-19 no Brasil foi registrado no dia 26 de Fevereiro de 2020. No dia 17 de Março, foi confirmada a primeira morte, 20 dias após o registro do primeiro caso no país.

# %% [markdown]
# ### **Casos no Brasil**
#
# Abaixo, plotaremos os gráficos em escala linear e logarítimica para os casos totais e mortes no Brasil.

# %%
# Gráficos de linha em escalas linear e logarítmica para os casos totais
x = list(range(df_brasil.shape[0]))
z = df_brasil['total_cases']

def millions(x, pos):
    """The two arguments are the value and tick position."""
    return '{:1.0f}M'.format(x*1e-6)
formatter = FuncFormatter(millions)


fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9, 7))
ax1.set_title('Casos no Brasil')
ax1.set_xlabel('Dias')
ax1.set_ylabel('Casos')
ax1.yaxis.set_major_formatter(formatter)
ax1.plot(x, z)

ax2.set_title('Casos no Brasil (Escala logarítmica)')
ax2.set_xlabel('Dias')
ax2.set_ylabel('Casos')
ax2.set_yscale('log')
ax2.plot(x, z)

plt.tight_layout()

# %% [markdown]
# Conforme já demonstrado no ranking dos países, o Brasil teve aproximadamente 35 milhões de casos de COVID-19, durante quase 3 anos de pandemia.

# %% [markdown]
# ### **Mortes no Brasil**

# %%
# Gráficos de linha em escalas linear e logarítmica para as mortes no Brasil
x = list(range(df_brasil.shape[0]))
z = df_brasil['total_deaths']

def millions(x, pos):
    """The two arguments are the value and tick position."""
    return '{:1.0f}k'.format(x*1e-3)
formatter = FuncFormatter(millions)

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9, 7))
ax1.set_title('Mortes no Brasil')
ax1.set_xlabel('Dias')
ax1.set_ylabel('Mortes')
ax1.yaxis.set_major_formatter(formatter)
ax1.plot(x, z)

ax2.set_title('Mortes no Brasil (Escala logarítmica)')
ax2.set_xlabel('Dias')
ax2.set_ylabel('Mortes')
ax2.set_yscale('log')
ax2.plot(x, z)

plt.tight_layout()

# %% [markdown]
# O Brasil somou mais de 700 mil mortes atribuídas ao COVID-19, durante quase 3 anos de pandemia.

# %% [markdown]
# ## Conclusão
#
# A pandemia do COVID-19 alcançou os quartro cantos da terra. Desde os países mais desenvolvidos até os do terceiro mundo sofreram com as consequências dessa doença.
# Observamos na curva logaritimica o qual rápido o número de casos e de mortes disparou no Brasil, já nos primeiros cem dias.
# Já se observa uma grande diminuição da força da pandemia. O diagnóstico e o tratamento da doença estão bem mais consolidados. Aliado a isso, temos a imunização da população via vacina, dados que não foram considerados nesta análise.
#
# Apesar disso, a pandemia ainda entá em andamento e os casos e mortes continuam altos.
